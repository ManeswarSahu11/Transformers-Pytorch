# %% [markdown]
# <a href="https://colab.research.google.com/github/ManeswarSahu11/Transformers-Pytorch/blob/main/implementation%20transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %ls
# Out:
# sample_data/

# %%
# %ls
# Out:
# Colab_Train.ipynb  Inference.ipynb   sample_data/
# config.py          model.py          train.py
# dataset.py         requirements.txt  translate.py

# %%
# !pip install -r requirements.txt
# Out:
# ERROR: Could not find a version that satisfies the requirement torch==2.0.1 (from versions: 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0, 2.7.0, 2.7.1, 2.8.0, 2.9.0, 2.9.1, 2.10.0)
# ERROR: No matching distribution found for torch==2.0.1

# %%
# !pip install torch torchvision sentencepiece tqdm

# %%
# !python train.py
# !python translate.py "I love machine learning"
# Out:
# Traceback (most recent call last):
#   File "/content/train.py", line 5, in <module>
#     import torchtext.datasets as datasets
# ModuleNotFoundError: No module named 'torchtext'
# Using device: cuda
# Traceback (most recent call last):
#   File "/content/translate.py", line 79, in <module>
#     translate(sys.argv[1] if len(sys.argv) > 1 else "I am not a very good a student.")
#   File "/content/translate.py", line 15, in translate
#     tokenizer_src = Tokenizer.from_file(str(Path(config['tokenizer_file'].format(config['lang_src']))))
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Exception: No such file or directory (os error 2)

# %%
# !pip install torchtext
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 49.4 MB/s eta 0:00:00
# ...

# %%
# !pip install torchtext datasets tokenizers torchmetrics tensorboard
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 34.6 MB/s eta 0:00:00
# ...

# %%
# !python train.py
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/torch/_ops.py", line 1488, in load_library
#     ctypes.CDLL(path)
#   File "/usr/lib/python3.12/ctypes/__init__.py", line 379, in __init__
#     self._handle = _dlopen(self._name, mode)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^
# OSError: /usr/local/lib/python3.12/dist-packages/torchtext/lib/libtorchtext.so: undefined symbol: _ZN5torch6detail10class_baseC2ERKSsS3_SsRKSt9type_infoS6_
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/content/train.py", line 5, in <module>
#     import torchtext.datasets as datasets
#   File "/usr/local/lib/python3.12/dist-packages/torchtext/__init__.py", line 18, in <module>
#     from torchtext import _extension  # noqa: F401
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torchtext/_extension.py", line 64, in <module>
#     _init_extension()
# ...

# %%
# !pip install datasets tokenizers torchmetrics tensorboard

# %%
# !python train.py
# Out:
# 2026-02-07 01:07:37.902231: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770426457.937274    4788 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770426457.948011    4788 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770426457.974120    4788 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python train.py
# Out:
# 2026-02-07 01:08:20.452712: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770426500.474568    4985 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770426500.481307    4985 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770426500.497989    4985 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python train.py
# Out:
# 2026-02-07 01:11:43.436368: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770426703.469659    5867 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770426703.480526    5867 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770426703.506741    5867 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python train.py
# Out:
# 2026-02-07 01:32:09.600030: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770427929.621071   11116 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770427929.627233   11116 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770427929.643447   11116 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
